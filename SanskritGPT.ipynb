# %% [markdown]
# <a href="https://colab.research.google.com/github/AryanSant27/SanskritGPT/blob/main/SanskritGPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U transformers datasets peft accelerate bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 85.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 37.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.1/411.1 kB 33.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.7/354.7 kB 29.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 14.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 51.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.2 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig

model_id = "meta-llama/Llama-2-7b-hf"  # or mistralai/Mistral-7B-v0.1

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype="bfloat16"
)

model = AutoModelForCausalLM.from_pretrained(
    model_id,
    quantization_config=bnb_config,
    device_map="auto"
)

tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
from datasets import load_dataset

dataset = load_dataset("diabolic6045/Sanskrit-llama")
train_data = dataset["train"]
# Out:
# README.md:   0%|          | 0.00/579 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/4.60M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/20227 [00:00<?, ? examples/s]

# %%
def format_instruction(example):
    if example["input"]:
        return f"""### Instruction:
{example["instruction"]}

### Input:
{example["input"]}

### Response:
{example["output"]}"""
    else:
        return f"""### Instruction:
{example["instruction"]}

### Response:
{example["output"]}"""

train_data = train_data.map(lambda x: {"text": format_instruction(x)})
# Out:
# Map:   0%|          | 0/20227 [00:00<?, ? examples/s]

# %%
from transformers import AutoTokenizer

tokenizer.pad_token = tokenizer.eos_token  # just in case
tokenized_data = train_data.map(
    lambda x: tokenizer(x["text"], truncation=True, padding="max_length", max_length=512),
    batched=True
)
# Out:
# Map:   0%|          | 0/20227 [00:00<?, ? examples/s]

# %%
from peft import LoraConfig, get_peft_model, TaskType

lora_config = LoraConfig(
    r=8,
    lora_alpha=16,
    lora_dropout=0.05,
    bias="none",
    task_type=TaskType.CAUSAL_LM,
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],
    inference_mode=False
)

model = get_peft_model(model, lora_config)
model.print_trainable_parameters()
# Out:
# /usr/local/lib/python3.11/dist-packages/peft/mapping_func.py:73: UserWarning: You are trying to modify a model with PEFT for a second time. If you want to reload the model with a different config, make sure to call `.unload()` before.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/peft/tuners/tuners_utils.py:167: UserWarning: Already found a `peft_config` attribute in the model. This will lead to having multiple adapters in the model. Make sure to know what you are doing!
#   warnings.warn(
# trainable params: 19,988,480 || all params: 6,758,404,096 || trainable%: 0.2958

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="./sanskrit-lora",
    per_device_train_batch_size=2,
    gradient_accumulation_steps=4,
    max_steps=200,  # or num_train_epochs=3
    warmup_steps=10,
    learning_rate=2e-4,
    fp16=True,
    logging_steps=10,
    save_strategy="epoch",
    report_to="none"
)

# %%
from transformers import Trainer, DataCollatorForLanguageModeling

# Use this data collator for causal LM (i.e., text generation)
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_data,
    data_collator=data_collator,
)
trainer.train()
# Out:
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
#     <div>
#
#       <progress value='200' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [200/200 30:58, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.315700</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.915300</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.733900</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.664500</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.650400</td>
#     </tr>
#     <tr>
#       <td>60</td>
# ...

# %%
from transformers import BitsAndBytesConfig, AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype="bfloat16",  # or torch.float16 if you get an error
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4"
)

base_model = AutoModelForCausalLM.from_pretrained(
    "meta-llama/Llama-2-7b-hf",  # or your base model
    quantization_config=bnb_config,
    device_map="auto"
)

tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-hf")
model = PeftModel.from_pretrained(base_model, "./sanskrit-lora-final")
model.eval()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-c10283dcf735> in <cell line: 0>()
#       9 )
#      10
# ---> 11 base_model = AutoModelForCausalLM.from_pretrained(
#      12     "meta-llama/Llama-2-7b-hf",  # or your base model
#      13     quantization_config=bnb_config,
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     569             if model_class.config_class == config.sub_configs.get("text_config", None):
#     570                 config = config.get_text_config()
# --> 571             return model_class.from_pretrained(
#     572                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     573             )
#
# ...

# %%
from accelerate import infer_auto_device_map, init_empty_weights
from transformers import AutoConfig

config = AutoConfig.from_pretrained("meta-llama/Llama-2-7b-hf")

with init_empty_weights():
    model = AutoModelForCausalLM.from_config(config)

device_map = infer_auto_device_map(model, max_memory={"cuda": "14GiB", "cpu": "30GiB"})

base_model = AutoModelForCausalLM.from_pretrained(
    "meta-llama/Llama-2-7b-hf",
    quantization_config=bnb_config,
    device_map=device_map
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-6b248aaec216> in <cell line: 0>()
#       7     model = AutoModelForCausalLM.from_config(config)
#       8
# ----> 9 device_map = infer_auto_device_map(model, max_memory={"cuda": "14GiB", "cpu": "30GiB"})
#      10
#      11 base_model = AutoModelForCausalLM.from_pretrained(
#
# /usr/local/lib/python3.11/dist-packages/accelerate/utils/modeling.py in infer_auto_device_map(model, max_memory, no_split_module_classes, dtype, special_dtypes, verbose, clean_result, offload_buffers, fallback_allocation)
#    1342         no_split_module_classes,
#    1343         modules_to_treat,
# -> 1344     ) = _init_infer_auto_device_map(model, max_memory, no_split_module_classes, dtype, special_dtypes)
#    1345
#    1346     device_map = OrderedDict()
#
# ...

# %%
trainer.save_model("./sanskrit-lora-final")
tokenizer.save_pretrained("./sanskrit-lora-final")
# Out:
# ('./sanskrit-lora-final/tokenizer_config.json',
#  './sanskrit-lora-final/special_tokens_map.json',
#  './sanskrit-lora-final/tokenizer.model',
#  './sanskrit-lora-final/added_tokens.json',
#  './sanskrit-lora-final/tokenizer.json')

# %%
import gc
import torch

gc.collect()
torch.cuda.empty_cache()

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype="bfloat16",  # or torch.float16
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4"
)

model_id = "meta-llama/Llama-2-7b-hf"  # or whichever base model you used

base_model = AutoModelForCausalLM.from_pretrained(
    model_id,
    quantization_config=bnb_config,
    device_map="auto"  # auto handles CPU/GPU offload
)

tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from peft import PeftModel

# Path to your saved fine-tuned LoRA model
lora_path = "./sanskrit-lora-final"  # change if needed

model = PeftModel.from_pretrained(base_model, lora_path)
model.eval()
# Out:
# /usr/local/lib/python3.11/dist-packages/peft/peft_model.py:569: UserWarning: Found missing adapter keys while loading the checkpoint: ['base_model.model.model.layers.0.self_attn.q_proj.lora_A.default.weight', 'base_model.model.model.layers.0.self_attn.q_proj.lora_B.default.weight', 'base_model.model.model.layers.0.self_attn.k_proj.lora_A.default.weight', 'base_model.model.model.layers.0.self_attn.k_proj.lora_B.default.weight', 'base_model.model.model.layers.0.self_attn.v_proj.lora_A.default.weight', 'base_model.model.model.layers.0.self_attn.v_proj.lora_B.default.weight', 'base_model.model.model.layers.0.self_attn.o_proj.lora_A.default.weight', 'base_model.model.model.layers.0.self_attn.o_proj.lora_B.default.weight', 'base_model.model.model.layers.0.mlp.gate_proj.lora_A.default.weight', 'base_model.model.model.layers.0.mlp.gate_proj.lora_B.default.weight', 'base_model.model.model.layers.0.mlp.up_proj.lora_A.default.weight', 'base_model.model.model.layers.0.mlp.up_proj.lora_B.default.
# ...

# %%
def generate_prompt(instruction, input_text=""):
    if input_text:
        return f"""### Instruction:
{instruction}

### Input:
{input_text}

### Response:"""
    else:
        return f"""### Instruction:
{instruction}

### Response:"""

# %%
import torch

def generate_response(instruction, input_text=""):
    prompt = generate_prompt(instruction, input_text)
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=200,
            temperature=0.7,
            top_p=0.9,
            do_sample=True,
            repetition_penalty=1.1,
            pad_token_id=tokenizer.eos_token_id  # prevent padding warning
        )

    decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return decoded

# %%
instruction = "Translate this English text to Sanskrit"
input_text = "If you know the enemy and know yourself, you need not fear the result of a hundred battles."

response = generate_response(instruction, input_text)
print(response)
# Out:
# ### Instruction:
# Translate this English text to Sanskrit
#
# ### Input:
# If you know the enemy and know yourself, you need not fear the result of a hundred battles.
#
# ### Response:
# घटित होंगे परमाणु! हैरानी के बाद हम सच्ची उज्जवल हो जाएंगे।
